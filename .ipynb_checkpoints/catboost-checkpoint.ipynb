# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
none = pd.read_csv("./none/hello_world_from_markovka1555408829.csv")
rock = pd.read_csv("./rock/hello_world_from_markovka1555409016.csv")
kulack = pd.read_csv("./kulack/hello_world_from_markovka1555408883.csv")

# %%
none["type"] = 0

# %%
rock["kulack"] = 1

# %%
rock["type"] = 2

# %%
none
# Out:
#      Unnamed: 0      unixtime   emg0   emg1  type
# 0             0  1.555409e+09  501.0  509.0     0
# 1             1  1.555409e+09  507.0  510.0     0
# 2             2  1.555409e+09  508.0  508.0     0
# 3             3  1.555409e+09  506.0  509.0     0
# 4             4  1.555409e+09  508.0  509.0     0
# 5             5  1.555409e+09  511.0  511.0     0
# 6             6  1.555409e+09  509.0  506.0     0
# 7             7  1.555409e+09  506.0  507.0     0
# 8             8  1.555409e+09  508.0  507.0     0
# 9             9  1.555409e+09  508.0  510.0     0
# 10           10  1.555409e+09  503.0  511.0     0
# 11           11  1.555409e+09  499.0  513.0     0
# 12           12  1.555409e+09  499.0  513.0     0
# 13           13  1.555409e+09  509.0  512.0     0
# 14           14  1.555409e+09  510.0  510.0     0
# 15           15  1.555409e+09  503.0  511.0     0
# 16           16  1.555409e+09  508.0  512.0     0
# 17           17  1.555409e+09  521.0  510.0     0
# ...

# %%
plot(kulack['Unnamed: 0'], kulack['emg1'])
